# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from nilearn import plotting, datasets, surface  

class SummaryVisualization:
    
    def __init__(self, paths):
        self.fsaverage_mesh_right = paths['fsaverage_mesh_right']
        self.fsaverage_sulc_right = paths['fsaverage_sulc_right']
        self.fsaverage_annot_right = paths['fsaverage_annot_right']
        self.fsaverage_mesh_left = paths['fsaverage_mesh_left']
        self.fsaverage_sulc_left = paths['fsaverage_sulc_left']
        self.fsaverage_annot_left = paths['fsaverage_annot_left']
        self.economo_summary_path = paths['economo_summary_path']
        
        # models summary
        data = pd.read_csv(self.economo_summary_path, index_col = 0)
        rh_data = data[data.Hemisphere == 0]
        lh_data = data[data.Hemisphere == 1]
        # mesh of average brain to create visualization on it
        rh_mesh = pd.Series(list(surface.load_surf_data(self.fsaverage_annot_right)), name='atlas').reset_index()
        lh_mesh = pd.Series(list(surface.load_surf_data(self.fsaverage_annot_left)), name='atlas').reset_index()
        # merge
        self.rh_summary_fsaverage = rh_data.merge(rh_mesh, left_on='atlas_x', right_on='atlas', how='right')
        self.lh_summary_fsaverage = lh_data.merge(lh_mesh, left_on='atlas_x', right_on='atlas', how='right')
        self.description = self.rh_summary_fsaverage.columns 


    def plot_cortex(self, column, cmap,  threshold = False):
        plt.hist(self.lh_summary_fsaverage[[column]], bins=40, color = '#582c9d')
        plt.title("Histogram of "+column+" in left hemisphere")
        plt.show()

        for view in ['lateral', 'medial']:#, 'dorsal', 'ventral', 'anterior', 'posterior']):
            plotting.plot_surf_stat_map(surf_mesh = self.fsaverage_mesh_left, 
                                              stat_map = np.array(self.lh_summary_fsaverage[[column]]), 
                                              bg_map = self.fsaverage_sulc_left,
                                              hemi = 'left', 
                                              view = view,
                                              title = column +' | '+view +' view of left hemisphere ',
                                              colorbar = True,
                                              cmap = cmap,
                                              threshold=threshold,
                                              symmetric_cbar = False,
                                              bg_on_data = True,
                                                   ) 
            plotting.show()

            plotting.plot_surf_stat_map(surf_mesh = self.fsaverage_mesh_right, 
                                              stat_map = np.array(self.rh_summary_fsaverage[[column]]), 
                                              bg_map = self.fsaverage_sulc_right,
                                              hemi = 'right', 
                                              view = view,
                                              title = view +' view of right hemisphere ',
                                              colorbar = True,
                                              cmap = cmap,
                                              threshold=threshold,
                                              symmetric_cbar = False,
                                              bg_on_data = True,
                                                   ) 
            plotting.show()


    def plot_atlas_all(self, cmap = 'Purples'):
        dummies_left = pd.get_dummies(self.lh_summary_fsaverage.atlas)
        for col in dummies_left.columns:
            name = str(np.array(df[df.atlas == col].structure_name.head(1))[0])
            plotting.plot_surf_stat_map(surf_mesh = self.fsaverage_mesh_left, 
                                              stat_map = np.array(dummies_left[col].astype(int)), 
                                              bg_map = self.fsaverage_sulc_left,
                                              hemi = 'left', 
                                              view = 'lateral',
                                              title = name +' | Structure: '+ str(col),
                                              #colorbar = True,
                                              cmap = cmap,
                                              symmetric_cbar = False,
                                              threshold=0.5,
                                              bg_on_data = True,
                                                   ) 
            plotting.show()
                
                
    def plot_atlas(self, n_structure, cmap = 'Purples'):
        dummies_left = pd.get_dummies(self.lh_summary_fsaverage.atlas)
        name = str(np.array(df[df.atlas == n_structure].structure_name.head(1))[0])
        for view in ['lateral','medial','dorsal','ventral']:
            plotting.plot_surf_stat_map(surf_mesh = self.fsaverage_mesh_left, 
                                              stat_map = np.array(dummies_left[n_structure].astype(int)), 
                                              bg_map = self.fsaverage_sulc_left,
                                              hemi = 'left', 
                                              view = view,
                                              title = name +' | Structure: '+ str(n_structure)+' | ' +view +' view of left hemisphere ',
                                              #colorbar = True,
                                              cmap = cmap,
                                              #symmetric_cbar = False,
                                              threshold=0.5,
                                              #bg_on_data = True,
                                                   ) 
            plotting.show()

# %%
path = {
    'fsaverage_mesh_right' : '/home/brunovieira/backup/Tamires_Experiments/Data/Economo/rh.pial',
    'fsaverage_sulc_right' : '/home/brunovieira/backup/Tamires_Experiments/Data/Economo/rh.avg_sulc' ,
    'fsaverage_annot_right' : '/home/brunovieira/backup/Tamires_Experiments/Data/Economo/rh.Eco.annot' ,
    
    'fsaverage_mesh_left' : '/home/brunovieira/backup/Tamires_Experiments/Data/Economo/lh.pial',
    'fsaverage_sulc_left' : '/home/brunovieira/backup/Tamires_Experiments/Data/Economo/lh.avg_sulc',
    'fsaverage_annot_left' : '/home/brunovieira/backup/Tamires_Experiments/Data/Economo/lh.Eco.annot' ,

    'economo_summary_path' : '/home/brunovieira/backup/Tamires_Experiments/Data/Economo/economo_summary_data.csv'
}

# %%
sv = SummaryVisualization(path)
sv.description
# Out:
# Index(['atlas_x', 'Hemisphere', 'Lobe', 'Thickness at 10y.o.',
#        'Thickness at 80y.o.', 'Curvature', 'Layer I thickness',
#        'Layer II thickness', 'Layer III thickness', 'Layer IV thickness',
#        'Layer V thickness', 'Layer VI thickness', 'bigbrain_layer_1',
#        'bigbrain_layer_2', 'bigbrain_layer_3', 'bigbrain_layer_4',
#        'bigbrain_layer_5', 'bigbrain_layer_6', 'Global thinning',
#        'Global thinning normalized', 'structure', 'r2_spatial', 'r2_temporal',
#        'r2_complete', 'structure_name', 'atlas_y', 'index', 'atlas'],
#       dtype='object')

# %%
sv.plot_cortex(column = 'Global thinning normalized', cmap = 'winter') 
#referencia cmap : Wistia, hsv, jet, rainbow, 'viridis', 'plasma', 'inferno', 'magma', 'cividis', winter

# %%
sv.plot_atlas_all()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 sv.plot_atlas_all()
#
# Cell In[70], line 81, in SummaryVisualization.plot_atlas_all(self, cmap)
#      68 name = str(np.array(df[df.atlas == col].structure_name.head(1))[0])
#      69 plotting.plot_surf_stat_map(surf_mesh = self.fsaverage_mesh_left,
#      70                                   stat_map = np.array(dummies_left[col].astype(int)),
#      71                                   bg_map = self.fsaverage_sulc_left,
#    (...)
#      79                                   bg_on_data = True,
#      80                                        )
# ---> 81 plotting.show()
#
# File ~/.conda/envs/tamires/lib/python3.10/site-packages/nilearn/plotting/img_plotting.py:57, in show()
#      49 """Show all the figures generated by nilearn and/or matplotlib.
#      50
# ...

# %% [markdown]
# ### Wich cortical structure thin more in life?

# %%
df = sv.rh_summary_fsaverage
number_structre = int(df.sort_values(by='Global thinning').atlas.head(1))
sv.plot_atlas(number_structre)
